# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi-dev07/Pandas_Library/blob/Lib/10_Saving_Your_Work_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load the Dataset

# %%
import pandas as pd
df = pd.read_excel('Call-Center-Sentiment-Sample-Data.xlsx', skiprows=4)

# %% [markdown]
# #Convert the excel to CSV

# %%
df.to_csv("converted_file.csv", index=False)
print(df.head())
# Out:
#    Unnamed: 0    Unnamed: 1         Unnamed: 2     Unnamed: 3  Unnamed: 4  \
# 0         NaN            ID      Customer Name      Sentiment  CSAT Score
# 1         NaN  PIS-39858047  Frances Gullefant        Neutral           8
# 2         NaN  ROH-40287216  Harcourt Zoanetti       Negative           5
# 3         NaN  NKC-39578431  Washington Oxteby       Negative           3
# 4         NaN  APY-17008648       Rafe Duffitt  Very Negative           4
#
#             Unnamed: 5        Unnamed: 6  Unnamed: 7     Unnamed: 8  \
# 0       Call Timestamp            Reason        City          State
# 1  2024-01-01 00:00:00  Billing Question  Charleston  West Virginia
# 2  2024-01-01 00:00:00  Billing Question    Honolulu         Hawaii
# 3  2024-01-02 00:00:00  Billing Question      Dallas          Texas
# 4  2024-01-02 00:00:00  Billing Question  Fort Myers        Florida
#
#     Unnamed: 9    Unnamed: 10              Unnamed: 11     Unnamed: 12
# ...
